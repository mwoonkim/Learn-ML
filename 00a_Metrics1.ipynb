# %% [markdown]
# <a href="https://colab.research.google.com/github/mwoonkim/Learn-ML/blob/main/00a_Metrics1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
# Sample Data
X = [[1], [2], [3], [4], [5]]
y = [1.2, 1.9, 3.0, 3.8, 5.1]
y_test = [1.01, 1.99, 3.05, 3.95, 5.05]
y_pred = [0.99, 2.01, 3.10, 3.90, 5.00]

# %%
# MAE (Mean Absolute Error)
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test, y_pred)
print("MAE:", mean_absolute_error(y_test, y_pred))
# Out:
# MAE: 0.038000000000000034

# %%
# RMSE (Root Mean Squared Error)
from sklearn.metrics import mean_squared_error
MSE = mean_squared_error(y_test, y_pred)
np.sqrt(MSE)
# Out:
# np.float64(0.04074309757492679)

# %%
# Confusion Matrix
from sklearn import metrics
confusion_matrix = metrics.confusion_matrix(y_test, y_pred)
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix, display_labels = [0,1])

# %%
cm_display.plot()
