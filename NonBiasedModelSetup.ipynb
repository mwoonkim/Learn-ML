# %% [markdown]
# <a href="https://colab.research.google.com/github/mwoonkim/Learn-ML/blob/main/NonBiasedModelSetup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
data =  pd.read_csv(“data.csv”)
Y = data.iloc[:,6:7]
X = data.drop(columns=[‘w’])

# %%
# 모델 설정 (예, gnb)
from sklearn.model_selection import ShuffleSplit # Monte Carlo Cross Validation (Shuffle Split)
mc = ShuffleSplit(n_splits=5, test_size=0.33, random_stat=7)
cross_val_score(gnb, X, Y.values.reshape(-1), cv=mc).mean()

# %%
from sklearn.model_selection import cross_val_score # K-Fold Cross Validation
from sklearn.model_selection import KFold
kf = KFold(n_splits=5)
cross_val_score(gnb, X, Y.values.reshape(-1), cv=kf).mean()

# %%
from skpearn.model_selection import LeaveOneOut  # Leave One Out Cross Validation
loo = LeaveOneOut()
for i, (train_idx, test_idx) in enumerate(loo.split(X)):

# %%
for train_idx, test_idx in loo.split(X):
     X_train, X_test = X[train_idx], X[test_idx]
     y_train, y_test = y[train_idx], y[test_idx]

# %%
from sklearn import cross_validation  # Bootstrapping
bs = cross_validation.Bootstrap(numberofdataset, n_bootstrap=3, n_train=0.5, n_test=None, random_state=None)
