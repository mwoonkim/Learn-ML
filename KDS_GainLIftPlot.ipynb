# %% [markdown]
# <a href="https://colab.research.google.com/github/mwoonkim/Learn-ML/blob/main/KDS_GainLIftPlot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kds

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn import tree
import kds

X, y = load_iris(return_X_y=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33,random_state=3)
clf = tree.DecisionTreeClassifier(max_depth=1,random_state=3)
clf = clf.fit(X_train, y_train)
y_prob = clf.predict_proba(X_test)

import kds
kds.metrics.plot_lift(y_test, y_prob[:,1])

# %%
kds.metrics.plot_cumulative_gain(y_test, y_prob[:,1])

# %%
kds.metrics.decile_table(y_test, y_prob[:,1])

# %%
kds.metrics.plot_ks_statistic(y_test, y_prob[:,1])
